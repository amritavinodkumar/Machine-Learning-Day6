# %%
import numpy as np

# %%
lis = [1,2,3,4,5,6,90]
ar = np.array(lis)
print(type(ar))
# Out:
# <class 'numpy.ndarray'>

# %%
print(np.mean(ar))
print(sum(ar)/len(ar))
# Out:
# 15.857142857142858
# 15.857142857142858

# %% [markdown]
# Whenever we r dealing with median, first we have sort their values is ascending order

# %%
ar.sort()
print(np.median(ar))
# Out:
# 4.0
